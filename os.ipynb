# %%
import os 
print(os.getcwd())
# Out:
# c:\Users\HP\OneDrive\Desktop\Python language

# %%
print(os.mkdir('test_dir'))
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(os.mkdir('test_dir'))
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'test_dir'

# %%
import shutil 
shutil.copyfile('source.txt' , 'destination.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 import shutil
# ----> 2 shutil.copyfile('source.txt' , 'destination.txt')
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
#     262             with open(dst, 'wb') as fdst:
#     263                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source.txt'

# %%
import json
data = {'name':'lalit', 'age':32}
json_str = json.dumps(data)
print(json_str)
parsed_data = json.loads(json_str)
print(parsed_data)
# Out:
# {"name": "lalit", "age": 32}
# {'name': 'lalit', 'age': 32}

# %%
from datetime import datetime,timedelta
now = datetime.now()
print(now)
yesterday = now - timedelta(days = 1)
print(yesterday)
# Out:
# 2025-07-26 15:11:24.642468
# 2025-07-25 15:11:24.642468
